# %% [markdown]
# #### 14.9 Относительную величину регулирующего объема $\Phi_{12}$ следует определять по формулам:
#
# **а)** при непрерывной работе насосной установки (водонагревателя) с различной производительностью в течение расчетного периода (сутки, смена) наибольшего водопотребления (теплопотребления) или работе насосной установки в режиме долгосрочных включений
#
# $$
# \Phi_1 = 1 - K_{\text{sp/hr}} + \left(K_{\text{hr}} - 1\right) * \frac{K_{\text{sp/hr}}}{K_{\text{hr}}}, \quad (23)
# $$
#
# **б)** при равномерной и непрерывной работе насосной установки (водонагревателя или генератора теплоты) в части периода водопотребления (теплопотребления), включающей также часы наибольшего водопотребления (теплопотребления):
#
# $$
# \Phi_2 = 1 - K_{\text{sp}} + \left(K_{\text{sp}} - 1\right) \frac{K_{\text{sp}}}{K_{\text{hr}}} + \frac{K_{\text{sp}}}{K_{\text{sp}} - 1}, \quad (24)
# $$
#
# ### Примечания
#
# 1. При расчете аккумуляторов теплоты по формулам (23) и (24) вместо значений $K_{\text{hr}}$ ($K_{\text{hr}}$, $K_{\text{sp}}$) следует принимать значения $K_{\text{hr}}^\prime$ и $K_{\text{sp}}^\prime$.
#
# 2. Значения $\Phi_1$ и $\Phi_2$, вычисленные по формулам (23) и (24), приведены в приложениях Д и Е.

# %%
from water_tank_storage import calculate_water_storage

# %%
calculate_water_storage(Qhhr_kW=4129, Qht_kW=1664, Qsp_kW=2962, T=12, th=65, tc=5, phi="A")
# Out:
# Расчет регулирующего объема бака-аккумулятора теплоты
# Исходные данные:
#   Режим работы: A
#   Расход тепла в час макс. водопотребления (Qhhr): 4129.0 кВт
#   Расход тепла в средний час (Qht): 1664.0 кВт
#   Расчетная мощность водоподогревателя (Qsp): 2962.0 кВт
#   Температура горячей воды (th): 65.0 °C
#   Температура холодной воды (tc): 5.0 °C
#   Период потребления (T): 12 ч
#
# Результаты расчета:
#   Коэффициент часовой неравномерности (K): 2.48
#   Коэффициент мощности (Ksp): 1.78
#   Коэффициент режима (φ): 0.07
#   Регулирующий объем бака (W1): 20.03 м³
# 20.03

# %%
calculate_water_storage(Qhhr_kW=4129, Qht_kW=1664, Qsp_kW=2962, T=24, th=65, tc=5, phi="A")
# Out:
# Расчет регулирующего объема бака-аккумулятора теплоты
# Исходные данные:
#   Режим работы: A
#   Расход тепла в час макс. водопотребления (Qhhr): 4129.0 кВт
#   Расход тепла в средний час (Qht): 1664.0 кВт
#   Расчетная мощность водоподогревателя (Qsp): 2962.0 кВт
#   Температура горячей воды (th): 65.0 °C
#   Температура холодной воды (tc): 5.0 °C
#   Период потребления (T): 24 ч
#
# Результаты расчета:
#   Коэффициент часовой неравномерности (K): 2.48
#   Коэффициент мощности (Ksp): 1.78
#   Коэффициент режима (φ): 0.07
#   Регулирующий объем бака (W1): 40.06 м³
# 40.06
