# %%
from Building import Building
from Level import Level
from Corridor import Corridor
from Room import Room
from Corridor_calculation import Corridor_calculation
from Tambour import Tambour
from Smoke_inlets import SmokeInlets

# %%
coridor_1 = SmokeInlets(
                corridor_height_m=3.0,
                G_min_kg_s=3.2,
                inlet_position="Vertical",
                inlet_height_m=0.45,
                inlet_width_m=0.4, 
                T_sm=437, 
            )

coridor_1.print_report()
# Out:
# gamma 0.5
# d 0.85
# Параметры системы дымоудаления
# --------------------------------------------------
#
# Высота коридора (м)                                  3.00
# Отметка низа дымоприемного (м)                       2.50
# Отметка дымового слоя (м)                           1.650
# Расстояние до слоя (м)                              0.850
# Эквивалентный диаметр (м)                           0.424
# Выполнено ли условие по высоте?                    True
# Выполнено ли условие по высоте выше двери?         True
# Расход продуктов горения (кг/с)                     3.200
# Высота дымоприемного устройства (м)                  0.45
# Ширина дымоприемного устройства (м)                  0.40
# Температура дыма (К)                                  437
# Температура воздуха (К)                               293
# Макс. расход на дымоприемное устройство (м³/с)      0.971
# Макс. расход на дымоприемное устройство (м³/ч)       3497
# Количество дымоприемных устройств, шт                 5.0
# Расстояние между дымоприемными устройствами мин, м    0.9
# Скорость в решетке, м/c                               4.9
