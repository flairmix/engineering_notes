# %% [markdown]
# #### 4.2.1 Лифтовые шахты центрального ядра надземной части, с остановками лифтов на уровнях только надземных этажей и с выгороженными лифтовыми холлами на каждом этаже, кроме нижнего

# %% [markdown]
# #### 4.2.2 Лифтовые шахты центрального ядра надземной части, с остановками лифтов на уровнях только надземных этажей и с выгороженными дифтовыми холлами на каждом этаже

# %% [markdown]
# #### 4.2.3 Лифтовые шахты у наружных ограждений, с остановками лифтов на уровнях только надземных этажей и с выгороженными лифтовыми холлами на каждом этаже

# %% [markdown]
# #### 4.2.4 Лифтовые шахты у наружных ограждений, с остановками лифтов на уровнях только надземных этажей и с выгороженными лифтовыми холлами на каждом этаже, кроме первого

# %% [markdown]
# #### 4.2.5 Лифтовые шахты подземные, с остановками лифтов на уровнях только на подземных и нижнем надземном и с выгороженными лифтовыми холлами на каждом этаже

# %% [markdown]
# #### 4.2.6 Лифтовые шахты, сообщающиеся с наземными и подземными этажами
#
# 4.2.6. При устройстве лифтовых шахт, сообщающихся с подземной и надземной частью, необходимо предусматривать
# раздельную подачу воздуха соответственно в верхнюю и нижнюю части защищаемых лифтовых шахт. Расчетные
# значения параметров при этом подлежат определению как по зависимостям (43)...(54), так и по зависимостям
# (55)... (58) - с учетом проектного размещения защищаемых лифтовых шахт и устройства этажных лифтовых холлов
# в надземной и подземной частях зданий.
#
# Причем давление в подземно-надземных частях защищаемых лифтовых шахт следует определять только по зависимости (55),
# а вычисленные значения расхода воздуха через открытые двери лифтовой шахты на основном посадочном этаже должны
# быть распределены в произвольном соотношении между обеими системами, обеспечивающими подачу воздуха в надземную
# и подземную части защищаемой лифтовой шахты.
