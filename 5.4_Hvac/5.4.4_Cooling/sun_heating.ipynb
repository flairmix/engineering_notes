# %% [markdown]
# ## Пособие 2.91 к СНиП 2.04-05-91 "Рачет поступлений теплоты солнечной радиации в помещения"

# %% [markdown]
# Поступления теплоты Q, Вт, в помещения от солнечной радиации определяется:
#
# $$
# Q = \sum\limits_{i=1}^a Q_i + \sum\limits_{i=1}^b Q_im \tag{1}
# $$
# - Q_i -  тепловой поток через i-й световое проем, Вт;\
# - Q_im - тепловой поток через i-й массивное ограждение, Вт;\
# - a - число световых проемов;\
# - b - число массивных ограждений;\

# %% [markdown]
# Тепловой поток прямой и рассеянной солнечной радтэции (далее "солнечной радиации") через i-й световой остекленный проем (далее "световой проем"), Вт, следует определять по формуле:
#
# $$
# Q_{sun} = Q_{sun,i} \cdot a_d + Q_{\delta t} \tag{2}
# $$
#
# - $Q_{sun}$ тепловой поток, Вт, солнечной радиации через остекленный световой проем, определяемый по п.п. 4-9;\
# - a_d - показатель поглощения теплового потока солнечной радиации, определяемый по п.п. 10-12;\
# - $Q_{\delta t}$ - тепловой поток теплопередачей через световой проем по п. 13.\

# %% [markdown]
# Тепловой поток, Вт, солнечной радиации через световой проем рассчитывается по формуле:
#
# $$
# Q_{sun, i} = (q_d \cdot K_1 + q_nd \cdot K_2) \cdot K3 \cdot K4 \cdot A_{gl} \tag{3}
# $$
#
# - $q_d, q_nd$ - поверхностная плотность теплового потока, Вт/кв.м, через остекленный световой проем в июле в данный час суток, соответственно от прямой (q_d) и рассеянной (q_nd) солнечной радиации,
# принимаемая для вертикального и горизонтального остекления по табл.1, а для наклонного остекления рассчитывается по п.5;\
# - $K_1$ - коэффициенты облученности прямой солнечной радиацией для учета плошали светового проема, незатененной горизонтальной К пг% и вертикальной К плоскостями в строительном исполнении, рис.1а, определяемые по п. 6;\
# - $K_2$ - коэффициенты облученности д я учета поступления рассеянной солнечной радиации через световые проемы, незатененные горизонтальной и вертикальной наружными солнцезащитными плоскостями з строительном исполнении, определяемые по п . 7;\
# - $K_3$ - коэффициенты теплопропускания солнцезащитных устройств (шторы, маркизы, жалюзи к др. изделия заводского изготовления), принимаемые по прил. 8 СНиП II-3-79**.\
# - $K_4$ - коэффициент теплопропускания остеклением световых проемов, принимаемые по табл'. 2;\
# - $A_{gl}$ - плошадь светового проема (остекления), кв.м.

# %% [markdown]
# 13. Тепловой поток теплопередачей, Вт, для данного часа суток через остекленный световой проем (остекление) рассчитывается по формуле:
#
# $$
# Q_{\delta t} = (t_{out-day-mid} + 0.5 \cdot A_{air-day} \cdot theta - t_{in}) \cdot (F_{m^2} / R) \tag{18}
# $$
#
#
# - $t_{out-day-mid}$ - средняя за сутки температура наружного воздуха, град.С, принимаемая равной температуре июля по графе 8 таблицы "Температура наружного воздуха" СНиП 2.01.01-82 [6];\
# - $A_{air-day}$ - максимальная суточная амплитуда температуры наружного воздуха в июле, град.С, принимаемая по СНиП 2.01.01-82;\
# - theta - коэффициент, выражающий гармоническое изменение температуры наружного воздуха, принимаемый по табл. 6 j\
# - $t_{in}$ - температура воздуха в помещении, град.С, принимаемая - по СНиП 2.04.05-91 [8];\
# - F, R - плошадь, кв.м, и приведенное сопротивление теплопередаче, кв.м град.С/Вт, остекления светового проема, принимаемое по прил. 6*СНиП II-3-79** или по табл.2 Пособия.\

# %% [markdown]
# 14. Тепловой поток, Вт, через массивную ограждающую конструкцию (наружную стену или покрытие) Q M, для данного часа суток (Z) следует определять по формуле:
#
# $$
# Q_m =  \left[ \frac{1}{R} \cdot a   \left( t_{out} + x_1\cdot \frac{j_{av}}{\alpha_{out}} - t_{in} \right) + \frac{\beta \cdot \alpha_{in}}{\upsilon} \cdot \left(  0.5 \cdot \theta_1 \cdot A_{air-day}+\frac{x_1}{\alpha_{out}}\cdot \theta_2 \cdot A_j   \right)  \right] \cdot A_m \tag{19}
# $$
#
#
# - R - сопротивление теплопередаче массивной ограждающей конструкции (наружной стены,покрытия), кв.м град.С/Вт, принимаемое в соответствии с требованиями п.п.2.6-2.9 СНиП. П-3-79**;\
# - 1нлр »t я * средняя температура наружного воздуха в июле, по СНиП 2.01.01-82 [6] и температура воздуха в помещении;\
# - f - коэффициент поглощения солнечной радиации поверхностью ограждающей конструкции, принимаемый по приложению 7 СНиП П-3-79** \
# - З ср - среднесуточное значение поверхностной плотности теплового потока суммарной солнечной радиации (прямой и рассеянной), Вт/кв.м, поступающей в июле следует принимать по табл.7 для горизонтальной и табл.8 для вертикальной поверхности\
# - коэффициент, равный 1 - при отсутствии вентилируемой воздушной прослойки в ограждении ( покрытии ) и равным 0,6 для всех других ограждающих конструкций;\
# - $\upsilon$ - величина затухания амплитуды колебаний температуры нарудного воздуха з ограждающей конструкции, определяемая по п.3.4* СНиП П-3-79** или по формуле\

# %%
from sun_rad_heating_functions import *

# %%
result_sun_base = pd.DataFrame(data_combined)

# %%
# df = calculation_sun_kW(
#     df_sun_base=result_sun_base,
#     A_m2_w = 20,
#     A_m2_e = 20,
#     A_m2_n = 0,
#     A_m2_s = 0,
#     t_out_day_mid = 23,
#     A_air_day = 24,
#     R = 1.45,
# )

# %%
t_out_day_mid = 23 # Средняя температура воздуха дневная
A_air_day = 24 # Амплитуда максимальная температуры воздуха

R = 1.45
K1 = 0.9  
K2 = 1  
K3 = 0.4  # шторы 
K4 = 0.34/0.87 #окна от производителя


# Площади остекления по сторонам света и по стоякам
f_C_1_1 = {
    'w' : 515,
    'e' : 636,
    'n' : 515,
    's' : 0,
}

f_C_1_2 = {
    'w' : 602,
    'e' : 466,
    'n' : 0,
    's' : 515,
}

f_C_2_1 = {
    'w' : 761,
    'e' : 888,
    'n' : 762,
    's' : 0,
}

f_C_2_2 = {
    'w' : 884,
    'e' : 761,
    'n' : 0,
    's' : 720,
}

Q_people_kW = {
    '1.1' : 28.7, 
    '1.2' : 31, 
    '2.1' : 25.3, 
    '2.2' : 29.6, 
}

Q_appliances_kW = {
    '1.1' : 57, 
    '1.2' : 53, 
    '2.1' : 52, 
    '2.2' : 53, 
}

# Общая площадь ограждений по зонам
f_C_1 = sum(f_C_1_1.values()) + sum(f_C_2_1.values())
f_C_2 = sum(f_C_1_2.values()) + sum(f_C_2_2.values())

# Общая площадь ограждений - W / E / N / S
f_C_W = f_C_1_1['w'] + f_C_1_2['w'] + f_C_2_1['w'] + f_C_2_2['w']
f_C_E = f_C_1_1['e'] + f_C_1_2['e'] + f_C_2_1['e'] + f_C_2_2['e']
f_C_N = f_C_1_1['n'] + f_C_1_2['n'] + f_C_2_1['n'] + f_C_2_2['n']
f_C_S = f_C_1_1['s'] + f_C_1_2['s'] + f_C_2_1['s'] + f_C_2_2['s']

# Общая площадь ограждений корпуса
f_C = f_C_1 + f_C_2

# Суммарное количество вытяжного воздуха 
L_m3_h = 48000

# Суммарное количество вытяжного воздуха разделенное в пропорции по площадям остекления 
L_m3_h_w = L_m3_h * (2/6)
L_m3_h_e = L_m3_h * (2/6)
L_m3_h_n = L_m3_h * (1/6)
L_m3_h_s = L_m3_h * (1/6)


# расход воздуха в пропорции от площадей остекления 
L_C_1_1_m3_h = (L_m3_h * (sum(f_C_1_1.values())) / f_C)
L_C_1_2_m3_h = (L_m3_h * (sum(f_C_1_2.values())) / f_C)
L_C_2_1_m3_h = (L_m3_h * (sum(f_C_2_1.values())) / f_C)
L_C_2_2_m3_h = (L_m3_h * (sum(f_C_2_2.values())) / f_C)

# L_m3_h * 1.2 * (t1 - t2) / 3600

# %%
L_C_2_2_m3_h
# Out:
# 14145.794392523365

# %%
print(f'Общая площадь ограждений - W - {f_C_W} м2')
print(f'Общая площадь ограждений - E - {f_C_E} м2')
print(f'Общая площадь ограждений - N - {f_C_N} м2')
print(f'Общая площадь ограждений - S - {f_C_S} м2')
# Out:
# Общая площадь ограждений - W - 2762 м2
# Общая площадь ограждений - E - 2751 м2
# Общая площадь ограждений - N - 1277 м2
# Общая площадь ограждений - S - 1235 м2

# %%
# df = calculation_sun_kW(
#     df_sun_base=result_sun_base,
#     A_m2_w = 20850,
#     A_m2_e = 20850,
#     A_m2_n = 19450,
#     A_m2_s = 19450,
#     t_out_day_mid = 23,
#     A_air_day = 24,
#     R = 1.45,
#     K1 = 0.9,     
#     K2 = 1,     
#     K3 = 0.4,     
#     K4 = 0.34/0.87, 
# )

# plot_df(df)

# %%
df_C_1_1 = calculation_sun_kW(
    df_sun_base=result_sun_base,
    A_m2_w = f_C_1_1['w'],
    A_m2_e = f_C_1_1['e'],
    A_m2_n = f_C_1_1['n'],
    A_m2_s = f_C_1_1['s'],
    Q_people_kW = Q_people_kW['1.1'],
    Q_appliances_kW = Q_appliances_kW['1.1'],
    L_m3_h = L_C_1_1_m3_h,
    t_out_day_mid = t_out_day_mid,
    A_air_day = A_air_day,
    R = R,
    K1 = K1,     
    K2 = K2,     
    K3 = K3,     
    K4 = K4, 
)

print(f'{df_C_1_1}')
print(f'{max(df_C_1_1['Q_sum'])} кВт')
print(f'{max(df_C_1_1['Q_sum'])} кВт / {f_C_1_1['w']+f_C_1_1['e']+f_C_1_1['n']+f_C_1_1['s']}')
print(f'{max(df_C_1_1['Q_sum']) /(f_C_1_1['w']+f_C_1_1['e']+f_C_1_1['n']+f_C_1_1['s']):.3f} кВт/м2')

plot_df(df_C_1_1)
# Out:
#     w_a_d  w_Q_sun_kW  e_a_d  e_Q_sun_kW  n_a_d  n_Q_sun_kW  s_a_d  s_Q_sun_kW  Q_people_kW  Q_appliances_kW  Rad_kW  theta_glass  Q_conduction_kW  t_air_out  delta_t_air_in_out  Q_heating_air_kW    Q_sum
# 01   0.13       0.000   0.09       0.000   0.09       0.000   0.10         0.0         28.7               57   0.000        -0.87          -13.144      12.56               -9.44             -31.0   41.556
# 02   0.11       0.000   0.09       0.000   0.09       0.000   0.10         0.0         28.7               57   0.000        -0.97          -14.523      11.36              -10.64             -35.0   36.177
# 03   0.11       0.000   0.08       0.000   0.08       0.000   0.10         0.0         28.7               57   0.000        -1.00          -14.937      11.00              -11.00             -37.0   33.763
# ...

# %%
df_C_1_2 = calculation_sun_kW(
    df_sun_base=result_sun_base,
    A_m2_w = f_C_1_2['w'],
    A_m2_e = f_C_1_2['e'],
    A_m2_n = f_C_1_2['n'],
    A_m2_s = f_C_1_2['s'],
    Q_people_kW = Q_people_kW['1.2'],
    Q_appliances_kW = Q_appliances_kW['1.2'],
    L_m3_h = L_C_1_2_m3_h,
    t_out_day_mid = t_out_day_mid,
    A_air_day = A_air_day,
    R = R,
    K1 = K1,     
    K2 = K2,     
    K3 = K3,     
    K4 = K4, 
)

plot_df(df_C_1_2)

# %%
df_C_2_1 = calculation_sun_kW(
    df_sun_base=result_sun_base,
    A_m2_w = f_C_2_1['w'],
    A_m2_e = f_C_2_1['e'],
    A_m2_n = f_C_2_1['n'],
    A_m2_s = f_C_2_1['s'],
    Q_people_kW = Q_people_kW['2.1'],
    Q_appliances_kW = Q_appliances_kW['2.2'],
    L_m3_h = L_C_2_1_m3_h,
    t_out_day_mid = t_out_day_mid,
    A_air_day = A_air_day,
    R = R,
    K1 = K1,     
    K2 = K2,     
    K3 = K3,     
    K4 = K4, 
)



plot_df(df_C_2_1)

# %%
df_C_2_2 = calculation_sun_kW(
    df_sun_base=result_sun_base,
    A_m2_w = f_C_2_2['w'],
    A_m2_e = f_C_2_2['e'],
    A_m2_n = f_C_2_2['n'],
    A_m2_s = f_C_2_2['s'],
    Q_people_kW = Q_people_kW['2.2'],
    Q_appliances_kW = Q_appliances_kW['2.2'],
    L_m3_h = L_C_2_2_m3_h,

    t_out_day_mid = t_out_day_mid,
    A_air_day = A_air_day,
    R = R,
    K1 = K1,     
    K2 = K2,     
    K3 = K3,     
    K4 = K4, 
)

plot_df(df_C_2_2)

# %%
df_C_1 = calculation_sun_kW(
    df_sun_base=result_sun_base,
    A_m2_w = f_C_1_1['w'] + f_C_1_2['w'],
    A_m2_e = f_C_1_1['e'] + f_C_1_2['e'],
    A_m2_n = f_C_1_1['n'] + f_C_1_2['n'],
    A_m2_s = f_C_1_1['s'] + f_C_1_2['s'],
    Q_people_kW= Q_people_kW['1.1'] + Q_people_kW['1.2'],
    Q_appliances_kW = Q_appliances_kW['1.1'] + Q_appliances_kW['1.2'],
    L_m3_h = L_C_1_1_m3_h + L_C_1_2_m3_h,
    t_out_day_mid = t_out_day_mid,
    A_air_day = A_air_day,
    R = R,
    K1 = K1,     
    K2 = K2,     
    K3 = K3,     
    K4 = K4,  
)

plot_df(df_C_1)

# %%
df_C_2 = calculation_sun_kW(
    df_sun_base=result_sun_base,
    A_m2_w = f_C_2_1['w'] + f_C_2_2['w'],
    A_m2_e = f_C_2_1['e'] + f_C_2_2['e'],
    A_m2_n = f_C_2_1['n'] + f_C_2_2['n'],
    A_m2_s = f_C_2_1['s'] + f_C_2_2['s'],
    Q_people_kW= Q_people_kW['2.1'] + Q_people_kW['2.2'],
    Q_appliances_kW = Q_appliances_kW['2.1'] + Q_appliances_kW['2.2'],
    L_m3_h = L_C_2_1_m3_h + L_C_2_2_m3_h,
    t_out_day_mid = t_out_day_mid,
    A_air_day = A_air_day,
    R = R,
    K1 = K1,     
    K2 = K2,     
    K3 = K3,     
    K4 = K4, 
)

plot_df(df_C_2)

# %%
df_C = calculation_sun_kW(
    df_sun_base=result_sun_base,
    A_m2_w = f_C_W,
    A_m2_e = f_C_E,
    A_m2_n = f_C_N,
    A_m2_s = f_C_S,
    Q_people_kW = sum(Q_people_kW.values()),
    Q_appliances_kW = sum(Q_appliances_kW.values()),
    L_m3_h = L_m3_h,
    t_out_day_mid = t_out_day_mid,
    A_air_day = A_air_day,
    R = R,
    K1 = K1,     
    K2 = K2,     
    K3 = K3,     
    K4 = K4, 
)

print(df_C)

plot_df(df_C)
# Out:
#     w_a_d  w_Q_sun_kW  e_a_d  e_Q_sun_kW  n_a_d  n_Q_sun_kW  s_a_d  s_Q_sun_kW  Q_people_kW  Q_appliances_kW   Rad_kW  theta_glass  Q_conduction_kW  t_air_out  delta_t_air_in_out  Q_heating_air_kW    Q_sum
# 01   0.13       0.000   0.09       0.000   0.09       0.000   0.10       0.000        114.6              215    0.000        -0.87          -63.314      12.56               -9.44            -151.0  115.286
# 02   0.11       0.000   0.09       0.000   0.09       0.000   0.10       0.000        114.6              215    0.000        -0.97          -69.956      11.36              -10.64            -170.0   89.644
# 03   0.11       0.000   0.08       0.000   0.08       0.000   0.10       0.000        114.6              215    0.000        -1.00          -71.948      11.00              -11.00            -176.0   81.652
# ...
